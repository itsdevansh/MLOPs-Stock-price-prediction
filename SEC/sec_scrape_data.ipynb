# %%
from sec_edgar_downloader import Downloader
# Out:
# /Users/devanshk/Desktop/Stock-price-prediction/sp-project/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
d1 = Downloader("Mycompanyname", "mycompany@gmail-spoof.com")
d1.get("4", "AAPL")
# Out:
# Error occurred while downloading filing for accession number {}: {} 0000320193-24-000075 ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 d1 = Downloader("Mycompanyname", "mycompany@gmail-spoof.com")
# ----> 2 d1.get("4", "AAPL")
#
# File ~/Desktop/Stock-price-prediction/sp-project/lib/python3.9/site-packages/sec_edgar_downloader/_Downloader.py:164, in Downloader.get(self, form, ticker_or_cik, limit, after, before, include_amends, download_details)
#     158     form_options = ", ".join(self.supported_forms)
#     159     raise ValueError(
#     160         f"{form!r} forms are not supported. "
#     161         f"Please choose from the following: {form_options}."
#     162     )
# --> 164 num_downloaded = fetch_and_save_filings(
# ...
